# %% [markdown]
# tf.optimizers.
#
# 1) SGD  # Классический оптимизатор, который обновляет веса в направлении антиградиента функции потерь
# 2) Adam  # Оптимизатор, сочетающий в себе преимущества адаптивного градиентного спуска (Adagrad) и Root Mean Square Propagation (RMSprop).
# 3) RMSprop  # Оптимизатор адаптирует скорость обучения для каждого параметра на основе истории градиентов для этого параметра.
# 4) Adagrad  # Оптимизатор уменьшает скорость обучения для параметров, которые редко или никогда не обновлялись, и увеличивает скорость обучения для параметров, которые часто обновлялись
# 5) Adadelta  # Оптимизатор является расширением Adagrad и использует только последние градиенты для обновления параметров.
# 6) Adamax  # Оптимизатор является вариантом Adam, который использует бесконечную норму вместо L2 нормы для обновления параметров.
# 6) Nadam  # Оптимизатор является комбинацией методов Nesterov Accelerated Gradient (NAG) и Adam

# %% [markdown]
# `seaborn` - библиотека типо matplotlib для построения графиков

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from tensorflow import  keras
from keras.optimizers import SGD, Adam
from keras.layers import Normalization
from keras import layers
from keras.models import Sequential
import matplotlib.pyplot as plt

# %% [markdown]
# ## Импорт базы данных

# %%
df = pd.read_csv('C:\ML\DataBases/winequality-red.csv')
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %%
df['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3], dtype=int64)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# ## Разделение данных на тренировочные и тестовые

# %%
train = df.sample(frac=0.8, random_state=42)
test = df.drop(train.index)

# %%
train
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 803             7.7              0.56         0.08            2.50      0.114
# 124             7.8              0.50         0.17            1.60      0.082
# 350            10.7              0.67         0.22            2.70      0.107
# 682             8.5              0.46         0.31            2.25      0.078
# 1326            6.7              0.46         0.24            1.70      0.077
# ...             ...               ...          ...             ...        ...
# 16              8.5              0.28         0.56            1.80      0.092
# 1072            7.2              0.35         0.26            1.80      0.083
# 1574            5.6              0.31         0.78           13.90      0.074
# 546             7.5              0.55         0.24            2.00      0.078
# 658             7.2              0.52         0.07            1.40      0.074
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 803                  14.0                  46.0  0.99710  3.24       0.66
# 124                  21.0                 102.0  0.99600  3.39       0.48
# 350                  17.0                  34.0  1.00040  3.28       0.98
# 682                  32.0                  58.0  0.99800  3.33       0.54
# 1326                 18.0                  34.0  0.99480  3.39       0.60
# ...                   ...                   ...      ...   ...        ...
# 16                   35.0                 103.0  0.99690  3.30       0.75
# 1072                 33.0                  75.0  0.99680  3.40       0.58
# 1574                 23.0                  92.0  0.99677  3.39       0.48
# 546                  10.0                  28.0  0.99830  3.45       0.78
# 658                   5.0                  20.0  0.99730  3.32       0.81
#
#       alcohol  quality
# 803       9.6        6
# 124       9.5        5
# 350       9.9        6
# 682       9.8        5
# 1326     10.6        6
# ...       ...      ...
# 16       10.5        7
# 1072      9.5        6
# 1574     10.5        6
# 546       9.5        6
# 658       9.6        6
#
# [1279 rows x 12 columns]

# %%
test
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1               7.8              0.88         0.00             2.6      0.098
# 8               7.8              0.58         0.02             2.0      0.073
# 13              7.8              0.61         0.29             1.6      0.114
# 14              8.9              0.62         0.18             3.8      0.176
# 20              8.9              0.22         0.48             1.8      0.077
# ...             ...               ...          ...             ...        ...
# 1569            6.2              0.51         0.14             1.9      0.056
# 1570            6.4              0.36         0.53             2.2      0.230
# 1573            6.0              0.58         0.20             2.4      0.075
# 1583            6.2              0.46         0.29             2.1      0.074
# 1595            5.9              0.55         0.10             2.2      0.062
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 8                     9.0                  18.0  0.99680  3.36       0.57
# 13                    9.0                  29.0  0.99740  3.26       1.56
# 14                   52.0                 145.0  0.99860  3.16       0.88
# 20                   29.0                  60.0  0.99680  3.39       0.53
# ...                   ...                   ...      ...   ...        ...
# 1569                 15.0                  34.0  0.99396  3.48       0.57
# 1570                 19.0                  35.0  0.99340  3.37       0.93
# 1573                 15.0                  50.0  0.99467  3.58       0.67
# 1583                 32.0                  98.0  0.99578  3.33       0.62
# 1595                 39.0                  51.0  0.99512  3.52       0.76
#
#       alcohol  quality
# 1         9.8        5
# 8         9.5        7
# 13        9.1        5
# 14        9.2        5
# 20        9.4        6
# ...       ...      ...
# 1569     11.5        6
# 1570     12.4        6
# 1573     12.5        6
# 1583      9.8        5
# 1595     11.2        6
#
# [320 rows x 12 columns]

# %% [markdown]
# ## Разделение данных на признаки и метки

# %%
x_train, y_train = train.iloc[:, :-1], train.iloc[:, -1]
x_test,  y_test = test.iloc[:, :-1], test.iloc[:, -1]

# %% [markdown]
# ## Задаем нормализатор

# %%
normalizer = Normalization(input_dim=len(x_train.columns), axis=1)
# input_dim - количество  столбцов в массиве, axis=1 указывает, как будут нормализовываться данные
# (1 - по столбцам, None - по строкам)

normalizer.adapt(np.array(x_train))  # adapt показывает нормализотору пример данных, 
                                    # с которых он считывает метрики для скейла последующих данных

# %% [markdown]
# ## Компиляция модели

# %%
model = Sequential([
    normalizer,
    layers.Flatten(),
    layers.Dense(16,  activation='relu'),
    layers.Dense(32,  activation='relu'),
    layers.Dense(64,  activation='relu'),
    layers.Dense(128,  activation='relu'),
    layers.Dense(1)
])

# %%
model.compile(
    optimizer=SGD(learning_rate=0.01),  # шаг при процессе схождения весов (лучше брать от  0.001 до 0.1)
    loss='mse',
    metrics=['mae', 'mse']
)

# %%
callbacks = [keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0.01, patience=5, verbose=0)]

# keras.callbacks.ModelCheckpoint(filepath='model_{epoch:02d}.h5', save_best_only=True, monitor='val_loss', verbose=0) - сохранение модели во время обучения

# %% [markdown]
# ## Обучение модели

# %%
history = model.fit(
    x_train,
    y_train,
    validation_data=(x_test, y_test),
    batch_size=32,
    epochs=100,
    callbacks=callbacks,
    verbose=True # отображэть процесс обучения модели
)
# Out:
# Epoch 1/100
# 40/40 [==============================] - 0s 3ms/step - loss: 4.3968 - mae: 1.4818 - mse: 4.3968 - val_loss: 1.1826 - val_mae: 0.8653 - val_mse: 1.1826
# Epoch 2/100
# 40/40 [==============================] - 0s 980us/step - loss: 0.8437 - mae: 0.7282 - mse: 0.8437 - val_loss: 0.6841 - val_mae: 0.6206 - val_mse: 0.6841
# Epoch 3/100
# 40/40 [==============================] - 0s 878us/step - loss: 0.6397 - mae: 0.6311 - mse: 0.6397 - val_loss: 0.5552 - val_mae: 0.5648 - val_mse: 0.5552
# Epoch 4/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5556 - mae: 0.5894 - mse: 0.5556 - val_loss: 0.4626 - val_mae: 0.5055 - val_mse: 0.4626
# Epoch 5/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4984 - mae: 0.5538 - mse: 0.4984 - val_loss: 0.4279 - val_mae: 0.4858 - val_mse: 0.4279
# Epoch 6/100
# 40/40 [==============================] - 0s 952us/step - loss: 0.4772 - mae: 0.5434 - mse: 0.4772 - val_loss: 0.4114 - val_mae: 0.4741 - val_mse: 0.4114
# Epoch 7/100
# 40/40 [==============================] - 0s 814us/step - loss: 0.4630 - mae: 0.5335 - mse: 0.4630 - val_loss: 0.3832 - val_mae: 0.4545 - val_mse: 0.3832
# Epoch 8/100
# 40/40 [==============================] - 0s 832us/step - loss: 0.4479 - mae: 0.5238 - mse: 0.4479 - val_loss: 0.3758 - val_mae: 0.4539 - val_mse: 0.3758
# Epoch 9/100
# 40/40 [==============================] - 0s 770us/step - loss: 0.4410 - mae: 0.5204 - mse: 0.4410 - val_loss: 0.3745 - val_mae: 0.4545 - val_mse: 0.3745
# Epoch 10/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4269 - mae: 0.5099 - mse: 0.4269 - val_loss: 0.3706 - val_mae: 0.4544 - val_mse: 0.3706
# Epoch 11/100
# 40/40 [==============================] - 0s 932us/step - loss: 0.4213 - mae: 0.5050 - mse: 0.4213 - val_loss: 0.3849 - val_mae: 0.4775 - val_mse: 0.3849
# Epoch 12/100
# 40/40 [==============================] - 0s 846us/step - loss: 0.4244 - mae: 0.5082 - mse: 0.4244 - val_loss: 0.3604 - val_mae: 0.4465 - val_mse: 0.3604
# Epoch 13/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4124 - mae: 0.5002 - mse: 0.4124 - val_loss: 0.3604 - val_mae: 0.4423 - val_mse: 0.3604
# Epoch 14/100
# 40/40 [==============================] - 0s 811us/step - loss: 0.4143 - mae: 0.5025 - mse: 0.4143 - val_loss: 0.3586 - val_mae: 0.4578 - val_mse: 0.3586
# Epoch 15/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4087 - mae: 0.5005 - mse: 0.4087 - val_loss: 0.3624 - val_mae: 0.4441 - val_mse: 0.3624
# Epoch 16/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4080 - mae: 0.4972 - mse: 0.4080 - val_loss: 0.3508 - val_mae: 0.4392 - val_mse: 0.3508
# Epoch 17/100
# 40/40 [==============================] - 0s 969us/step - loss: 0.4023 - mae: 0.4933 - mse: 0.4023 - val_loss: 0.3494 - val_mae: 0.4428 - val_mse: 0.3494
# Epoch 18/100
# 40/40 [==============================] - 0s 856us/step - loss: 0.4006 - mae: 0.4936 - mse: 0.4006 - val_loss: 0.3455 - val_mae: 0.4442 - val_mse: 0.3455
# Epoch 19/100
# 40/40 [==============================] - 0s 886us/step - loss: 0.4145 - mae: 0.5023 - mse: 0.4145 - val_loss: 0.3467 - val_mae: 0.4401 - val_mse: 0.3467
# Epoch 20/100
# 40/40 [==============================] - 0s 809us/step - loss: 0.4004 - mae: 0.4896 - mse: 0.4004 - val_loss: 0.4121 - val_mae: 0.5087 - val_mse: 0.4121
# Epoch 21/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4013 - mae: 0.4905 - mse: 0.4013 - val_loss: 0.3455 - val_mae: 0.4499 - val_mse: 0.3455
# Epoch 22/100
# 40/40 [==============================] - 0s 981us/step - loss: 0.3913 - mae: 0.4842 - mse: 0.3913 - val_loss: 0.3683 - val_mae: 0.4571 - val_mse: 0.3683

# %%
x_test
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1               7.8              0.88         0.00             2.6      0.098
# 8               7.8              0.58         0.02             2.0      0.073
# 13              7.8              0.61         0.29             1.6      0.114
# 14              8.9              0.62         0.18             3.8      0.176
# 20              8.9              0.22         0.48             1.8      0.077
# ...             ...               ...          ...             ...        ...
# 1569            6.2              0.51         0.14             1.9      0.056
# 1570            6.4              0.36         0.53             2.2      0.230
# 1573            6.0              0.58         0.20             2.4      0.075
# 1583            6.2              0.46         0.29             2.1      0.074
# 1595            5.9              0.55         0.10             2.2      0.062
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 8                     9.0                  18.0  0.99680  3.36       0.57
# 13                    9.0                  29.0  0.99740  3.26       1.56
# 14                   52.0                 145.0  0.99860  3.16       0.88
# 20                   29.0                  60.0  0.99680  3.39       0.53
# ...                   ...                   ...      ...   ...        ...
# 1569                 15.0                  34.0  0.99396  3.48       0.57
# 1570                 19.0                  35.0  0.99340  3.37       0.93
# 1573                 15.0                  50.0  0.99467  3.58       0.67
# 1583                 32.0                  98.0  0.99578  3.33       0.62
# 1595                 39.0                  51.0  0.99512  3.52       0.76
#
#       alcohol
# 1         9.8
# 8         9.5
# 13        9.1
# 14        9.2
# 20        9.4
# ...       ...
# 1569     11.5
# 1570     12.4
# 1573     12.5
# 1583      9.8
# 1595     11.2
#
# [320 rows x 11 columns]

# %% [markdown]
# ## Проверка качества обучения модели

# %%
y_pred = model.predict(x_test)
y_pred = y_pred.reshape(-1,)

print(f'percentage correct: {np.sum(y_pred.round(0)==y_test.values)/len(y_test)*100}')
# Out:
# 10/10 [==============================] - 0s 503us/step
# percentage correct: 63.125

# %%
df = pd.DataFrame(y_pred, columns=['y_pred'])
df['y_test'] = y_test.values
df['is_true'] = df['y_pred'].round(0) == df['y_test']
df
# Out:
#        y_pred  y_test  is_true
# 0    5.273172       5     True
# 1    5.251549       7    False
# 2    5.655609       5    False
# 3    4.870350       5     True
# 4    4.889656       6    False
# ..        ...     ...      ...
# 315  5.475985       6    False
# 316  6.297688       6     True
# 317  5.704044       6     True
# 318  5.182251       5     True
# 319  6.012862       6     True
#
# [320 rows x 3 columns]

# %% [markdown]
# ## Графики, описывающие качество обучения модели

# %%
def plot_graphs(y_pred, y_test, figsize=(12, 12), fontsize=15):
    # рисую гистограмму

    plt.figure(figsize=figsize)

    plt.subplot(1, 2, 1)
    plt.hist((y_pred-y_test)*100/len(y_test))
    plt.title('MAE', fontsize=fontsize)

    # рисую график отклонения предиктов от идеала
    plt.subplot(1, 2, 2)
    plt.scatter(y_test, y_pred)
    plt.plot([min(y_test)-1, max(y_test)+1], [min(y_test)-1, max(y_test)], c='red')
    plt.title('Deviation from the ideal', fontsize=fontsize)

# %%
plot_graphs(y_pred, y_test.values)
